# %%
import json

with open("c8.all.v2023.2.Hs.symbols.json", "r") as f:
    data = json.load(f)

# %%
len(data.keys())
# Out:
# 116

# %%
num = 0
for key in data.keys():
    num += len(data[key])
num
# Out:
# 18349

# %%
s = set()
for key in data.keys():
    for item in data[key]:
        s.add(item)
len(s)
# Out:
# {'F2RL1',
#  'ALAS1',
#  'CSF2RA',
#  'PNP',
#  'GPBP1',
#  'TMPRSS9',
#  'GALNT1',
#  'POU2AF1',
#  'APCDD1',
#  'GNB2',
#  'KLRC2',
#  'LUZP1',
#  'C6',
#  'PGM5',
#  'ALPK2',
#  'CBL',
#  'NDUFA4L2',
#  'PPP1R15B',
#  'MS4A7',
#  'IGFLR1',
#  'PRKD3',
#  'COL11A2',
#  'TM4SF19',
#  'ATP5PF',
#  'VWA5B1',
#  'SRPX2',
#  'MARVELD2',
#  'P4HB',
#  'N4BP1',
#  'SLC9A9',
#  'SAA4',
#  'CCL20',
#  'COX6CP17',
#  'TCF15',
#  'TM4SF4',
#  'SNRPE',
#  'HBZ',
#  'ENSG00000251314',
#  'SPCS3',
#  'CYP2D6',
#  'FTCD',
#  'FOXJ3',
#  'GRB14',
#  'GJA4',
#  'SLK',
#  'MEIS1',
#  'MOCS1',
#  'SOSTDC1',
#  'NSG2',
#  'NCOR1',
#  'MGP',
#  'HTRA3',
#  'C11orf21',
#  'ZC3H13',
#  'APOC4',
#  'LINC01194',
#  'UBE2D2',
#  'LY86',
#  'CASQ1',
#  'SBSN',
#  'RAET1G',
#  'CLEC9A',
#  'ZNF831',
#  'LRRC17',
#  'RAB39A',
#  'RAP1GAP',
#  'RPL36AL',
#  'RHOJ',
#  'ANGPTL4',
#  'CTSG',
#  'VPS26A',
#  'ANKRD12',
#  'CRLF3',
#  'FABP5',
#  'CNTRL',
#  'MYCT1',
#  'SNX17',
#  'SFRP5',
#  'FNDC1',
# ...

# %%
18349 / 116
# Out:
# 158.18103448275863
